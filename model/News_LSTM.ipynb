# %% [markdown]
# ## <center>The effects of the News on the VIX</center>

# %%
# package for data manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#package for time
from dateparser.search import search_dates
import datetime

# package for the regular expressions 
import re
import string

# package for the natural language toolkit 
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from keras.preprocessing import sequence
from keras.models import Sequential , Input
from keras.models import Model
from keras.layers import LSTM
from keras.layers import Dense, Embedding, Flatten, Dropout, Activation
from keras.layers.convolutional import Convolution1D
from keras.layers.convolutional import MaxPooling1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from keras.utils import plot_model

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data Scraping

# %% [markdown]
# ##### We connect to the yahoo finance site and we recover the value of the VIX

# %%
prices=[]
names=[]
changes=[]
percentChanges=[]

url = "https://in.finance.yahoo.com/world-indices"
data = requests.get(url).text
soup = BeautifulSoup(data)
 
def read_indice ():
    for row in soup.find_all('tbody'):
        for srow in row.find_all('tr'):
            for name in srow.find_all('td', attrs={'class':'data-col1'}):
                names.append(name.text)
            for price in srow.find_all('td', attrs={'class':'data-col2'}):
                prices.append(price.text)
            for change in srow.find_all('td', attrs={'class':'data-col3'}):
                changes.append(change.text)
            for percentChange in srow.find_all('td', attrs={'class':'data-col4'}):
                percentChanges.append(percentChange.text)
        df_indice = pd.DataFrame({"Names": names, "Prices": prices, "Change": changes, "% Change": percentChanges})
        return df_indice['Prices'].iloc[19]

# %%
read_indice()
# Out:
# '24.52'

# %% [markdown]
# ### Open the files that we use for analysis

# %%
data = pd.read_csv('C:/Users/anis_/PycharmProjects/mywebscrap/bloom/bloom/spiders/echo.csv' , encoding = 'utf-8')
data =data.dropna().reset_index(drop=True)
data['headline'] = data['headline'].astype(str)
data['description'] = data['description'].astype(str)
data
# Out:
#                                               headline  \
# 0                              Aérien : Folle descente
# 1    Bourses : les trois chiffres d'une journée sou...
# 2      EssilorLuxottica a tenu son cap dans la tempête
# 3    Coronavirus : vent de panique sur les marchés ...
# 4                 Dawn Hudson, au générique des Oscars
# ..                                                 ...
# 380  Goldman Sachs veut plus de femmes et de divers...
# 381  Bourse : 5 questions essentielles avant d'inve...
# 382  Les biotechs françaises en manque de «success ...
# 383       Assurance-vie : trois idées pour gagner plus
# 384  Après Kering, Sodexo met ses actionnaires mino...
#
#                                            description  \
# 0    La Bourse anticipe un horizon très bouché pour...
# 1    Les marchés ont connu cette semaine une intens...
# 2    Le nouveau géant mondial de l'optique a vu son...
# 3    Wall Street affiche de fortes baisses. Le CAC ...
# 4    Juste avant la journée des femmes, l'actrice, ...
# ..                                                 ...
# 380  A partir de juillet, la banque d'affaires amér...
# 381  L'investissement boursier est réputé être perf...
# 382  Malgré les mauvais résultats des biotechs en 2...
# 383  La cause est entendue, quiconque souhaite rent...
# 384  Les investisseurs qui dépassent 1 % du capital...
#
#                                                   date
# 0                             Publié le 6 mars à 18h22
# 1    En chiffres,Publié le 6 mars à 13h27,Mis à jou...
# 2    Publié le 6 mars à 10h54,Mis à jour le 8 mars ...
# 3    Publié le 6 mars à 9h58,Mis à jour le 9 mars à...
# 4                     Portrait,Publié le 6 mars à 9h15
# ..                                                 ...
# 380  Publié le 24 janv. à 13h02,Mis à jour le 24 ja...
# 381  Publié le 24 janv. à 8h26,Mis à jour le 24 jan...
# 382  Décryptage,Publié le 24 janv. à 7h16,Mis à jou...
# 383                          Publié le 24 janv. à 7h01
# 384                          Publié le 24 janv. à 6h00
#
# [385 rows x 3 columns]

# %%
def set_dates():
    
    date_list = []
    
    #Use the search_dates to extract the date from a string 
    for i in data['date']:
        dates = search_dates(i)
        timestamp = dates[-1][-1]
        date_list.append(timestamp)
    
    data['timestamp'] = date_list
    data['Date'] = ""    
    
    #Convert out output into a date format 
    for i, x in data['timestamp'].iteritems():
        data['Date'].loc[i] = datetime.datetime.strptime(str(x), '%Y-%m-%d %H:%M:%S').date()
    
    return data.sort_values(by = 'Date', ascending=False).reset_index(drop=True)

# %%
def open_vix_file():
    df_vix = pd.read_csv('VIX.csv')
    
    for i, x in df_vix['Date'].iteritems():
        df_vix['Date'].loc[i] = datetime.datetime.strptime(str(x), '%Y-%m-%d').date()
    
    return df_vix

# %%
def new_dataset():
    
    data = set_dates()
    df_vix = open_vix_file()
    data['Open'] = ""
    data['Close'] = ""
    
    #we look at the date of the article and we try to find the corresponding values in the Vix file
    for x in range(data.shape[0]):
        for i in range(df_vix.shape[0]):
            if(data['Date'].loc[x] == df_vix['Date'].loc[i]):
                data['Open'].loc[x] = df_vix['Open'].loc[i]
                data['Close'].loc[x] = df_vix['Close'].loc[i]
                break
    
    # If the closing value is greater than the opening value, the news is negative = 1
    data.replace('', np.nan, inplace=True)
    data = data.dropna().reset_index(drop=True)
    
    data['article'] = data['headline'].str.cat(data['description'], sep = ".")
    data['article'] = data['article'].astype(str) 
    data['label'] = ""
    
    df = data.drop('date', axis=1)
    df = df.drop('timestamp', axis = 1)
    df.drop('headline', axis = 1, inplace = True)
    df.drop('description', axis = 1, inplace = True)

    
    for x in range(df.shape[0]):
        if (df['Close'].loc[x]-df['Open'].loc[x] >= 0):
            df['label'].loc[x] = 0
        else :
            df['label'].loc[x] = 1
    
    df = df[['article', 'Date', 'Open', 'Close', 'label']]
    
    return df

# %%
df_news = new_dataset()

# %%
df_news
# Out:
#                                                article        Date       Open  \
# 0    Bourse : Réflexes naturels.Les investisseurs s...  2020-04-29  32.480000
# 1    La dynamique des «exit techs» coupée dans son ...  2020-04-28  33.209999
# 2    Coronavirus : ce qu'il faut retenir de la jour...  2020-04-28  33.209999
# 3    Bourse/Gafam : Ce qui se raréfie peut être ché...  2020-04-28  33.209999
# 4    150.000 particuliers ont fait leurs premiers p...  2020-04-28  33.209999
# ..                                                 ...         ...        ...
# 333  Les propositions du patronat pour lutter contr...  2019-12-12  14.940000
# 334  Volatilité/Bourse : L'envie de retour d'une gr...  2019-12-12  14.940000
# 335  Le vélo d'intérieur, le vendeur à découvert et...  2019-12-12  14.940000
# 336  Sanofi : ordonnance royale.Quand le nouveau pl...  2019-12-11  15.570000
# 337  Au Japon, les activistes visent tous les secte...  2019-12-11  15.570000
#
#      Close  label
# 0    31.23      1
# 1    33.57      0
# 2    33.57      0
# 3    33.57      0
# 4    33.57      0
# ..     ...    ...
# 333  13.94      1
# 334  13.94      1
# 335  13.94      1
# 336  14.99      1
# 337  14.99      1
#
# [338 rows x 5 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
def data_cleaning(text):
    '''
    Tout mettre en minuscule, enlever les ponctuations et les chiffres
    <<< NB: NE PAS UTILISER SUR LA COLONNE DATE >>>
    '''
    text = text.lower()
    text = re.sub('\[.*?\']',' ',text)
    text = re.sub('[%s]' % re.escape(string.punctuation),' ',text)
    text = re.sub('\w*\d\w*',' ',text)
    text = text.replace(u'\xa0', u' ')
    text = " ".join(text.split())

    return text

clean = lambda df: data_cleaning(df)

# %%
df_news['article'] = df_news['article'].apply(clean)

# %%
df_news
# Out:
#                                                article        Date       Open  \
# 0    bourse réflexes naturels les investisseurs son...  2020-04-29  32.480000
# 1    la dynamique des «exit techs» coupée dans son ...  2020-04-28  33.209999
# 2    coronavirus ce qu il faut retenir de la journé...  2020-04-28  33.209999
# 3    bourse gafam ce qui se raréfie peut être chéri...  2020-04-28  33.209999
# 4    particuliers ont fait leurs premiers pas en bo...  2020-04-28  33.209999
# ..                                                 ...         ...        ...
# 333  les propositions du patronat pour lutter contr...  2019-12-12  14.940000
# 334  volatilité bourse l envie de retour d une gran...  2019-12-12  14.940000
# 335  le vélo d intérieur le vendeur à découvert et ...  2019-12-12  14.940000
# 336  sanofi ordonnance royale quand le nouveau plan...  2019-12-11  15.570000
# 337  au japon les activistes visent tous les secteu...  2019-12-11  15.570000
#
#      Close  label
# 0    31.23      1
# 1    33.57      0
# 2    33.57      0
# 3    33.57      0
# 4    33.57      0
# ..     ...    ...
# 333  13.94      1
# 334  13.94      1
# 335  13.94      1
# 336  14.99      1
# 337  14.99      1
#
# [338 rows x 5 columns]

# %%
df_news['article'].loc[5]
# Out:
# 'coronavirus ce qu il faut retenir de la journée du avril la france a enregistré lundi décès supplémentaires en heures portant le bilan total de l épidémie à morts edouard philippe présentera mardi le plan de déconfinement alors que le chômage bondit et que plus d un parent sur deux ne souhaite pas renvoyer son enfant à l école'

# %%
def data_model():
    
    data = new_dataset()
    data['article'] = data['article'].str.lower()
    data['article'] = data['article'].apply(clean)
    
    data = data[['Date', 'article', 'label']]
    date = pd.unique(data['Date']).tolist()
    rows= []
        
    for i in date:
        df = data[data['Date'] == i]
        text = pd.unique(df['article']).tolist()
        sentiment = pd.unique(df['label']).tolist()
        rows.append([i,text,sentiment])
        
    df_article = pd.DataFrame(rows, columns = ['date', 'article', 'label'])
    
    
    ##pour pouvoir traiter le text, on doit l'avoir sous format list of list 
    for i,j in enumerate(df_article['article']):
        df_article['article'].loc[i] = [[a] for a in j]
    
    df_article['label'] = [item for sublist in df_article['label'] for item in sublist]

    return df_article

# %%
final_df = data_model()

# %%
final_df
# Out:
#           date                                            article  label
# 0   2020-04-29  [[bourse réflexes naturels les investisseurs s...      1
# 1   2020-04-28  [[la dynamique des «exit techs» coupée dans so...      0
# 2   2020-04-27  [[coronavirus ce qu il faut retenir de la jour...      1
# 3   2020-04-23  [[euronext se renforce en europe du nord l opé...      0
# 4   2020-04-22  [[lagardère vivendi amitiés particulières la s...      1
# ..         ...                                                ...    ...
# 87  2019-12-17  [[placements chasse à la bonne raison l évolut...      0
# 88  2019-12-16  [[le cac au dessus des points pour la première...      1
# 89  2019-12-13  [[trump et johnson rassurent les bourses asiat...      1
# 90  2019-12-12  [[les banques impliquées dans le plus grand sc...      1
# 91  2019-12-11  [[sanofi ordonnance royale quand le nouveau pl...      1
#
# [92 rows x 3 columns]

# %%
final_df['article'].loc[1]
# Out:
# [['la dynamique des «exit techs» coupée dans son élan le nombre de rachats ou d introductions en bourse de valeurs technologiques françaises avait connu un pic au début de l année face à la crise du coronavirus le flux des transactions est stoppé net'],
#  ['coronavirus ce qu il faut retenir de la journée du avril sans surprise les députés ont validé le plan de déconfinement du gouvernement lors d un vote consultatif après cinq heures de débat au total cas graves sont toujours traités dans les services de réanimation français soit patients en moins le nombre d hospitalisation est aussi en baisse au cours des dernières heures personnes sont décédées du nouveau coronavirus'],
#  ['bourse gafam ce qui se raréfie peut être chéri la croissance saine financièrement restera une denrée rare'],
#  ['particuliers ont fait leurs premiers pas en bourse depuis deux mois les particuliers ont cherché les bonnes affaires au plus fort de la tempête boursière entre fin février et début avril investisseurs particuliers ont acheté des actions du sbf dont plus de nouveaux venus']]

# %% [markdown]
# ## MODEL LSTM

# %% [markdown]
# On aimerait connaitres les stats descriptives concernant nos articles:
#     - nombre minimum d'article par jour
#     - nombre maximal d'article par jour
#     - mediam
#     - etc ...
#     -Aussi, faire la meme analyse par nombres de mots des articles
# Ceci nous permettra pour le pad_sequence

# %%
taille = []
for i in final_df['article']:
    taille.append(len(i))
print("le nombre d'article minimal est de ",np.min(taille))
print("le premier quantil est de ",np.quantile(taille, q=0.25))
print("le nombre d'article médian est de ",np.median(taille))
print("le nombre d'article moyen est de ",np.mean(taille))
print("le troisiéme quantile est de ",np.quantile(taille, q=0.75))
print("le nombre d'article maximal est de ",np.max(taille))
# Out:
# le nombre d'article minimal est de  1
# le premier quantil est de  2.0
# le nombre d'article médian est de  3.0
# le nombre d'article moyen est de  3.6739130434782608
# le troisiéme quantile est de  4.25
# le nombre d'article maximal est de  12

# %%
slen = []
for i in final_df['article']:
    for j in i:
        slen.append([len(s.split()) for s in j])

print("le nombre de mot minimal est de ",np.min(slen))
print("le premier quantil est de ",np.quantile(slen, q=0.25))
print("le nombre médian est de ",np.quantile(slen, q=0.5))
print("le nombre de mot moyen est de ",np.mean(slen))
print("le troisième quartile est de ",np.quantile(slen, q=0.75))
print("le nombre de mot maximal est de ",np.max(slen))
# Out:
# le nombre de mot minimal est de  13
# le premier quantil est de  38.25
# le nombre médian est de  49.0
# le nombre de mot moyen est de  46.97337278106509
# le troisième quartile est de  58.0
# le nombre de mot maximal est de  85

# %%
data = final_df

# %%
data.head(2)
# Out:
#          date                                            article  label
# 0  2020-04-29  [[bourse réflexes naturels les investisseurs s...      1
# 1  2020-04-28  [[la dynamique des «exit techs» coupée dans so...      0

# %%
def data_feature():
    
    #data = data_model()
    tknz = Tokenizer()
    max_length = 60
    max_article = 6
    shape = data.shape[0]
    global vocab_size
    global vocab
    #vocab_size = set()

    X = data['article']
    Y = data['label'].astype(np.float32)
    Y = np.asarray(Y)

    tok_data = [y[0] for x in X for y in x]
    tknz.fit_on_texts(tok_data)
    
    Z = data['article']
    Z = np.zeros((shape, max_article, max_length)).astype(np.float32)
    
    for j,i in enumerate(X):
        tmp = []
        for y in i:
            tmp.append(tknz.texts_to_sequences(y)[0])
            pad_seq = pad_sequences(sequences = tmp, maxlen = max_length, dtype = 'float32', padding = 'post', truncating = 'post')
            t = min(max_article, pad_seq.shape[0])
            pad_seq = pad_seq[:t]
            a = max_article - t
            Z[j][a:] = pad_seq
            #data['X'].loc[j] = Z[j][:]
    Z = Z.astype(np.float32)
    Z = Z.reshape(len(Z), max_article * max_length)
    vocab_size = len(tknz.word_index)+1
    vocab = tknz.word_index
    
    return Z, Y

# %%
def embedding_glove():

    glove_file = open('multilingual_embeddings.txt', encoding="utf8")
    embeddings_dictionary = dict()

    for line in glove_file:
        records = line.split()
        word = records[0]
        vector_dimensions = np.asarray(records[1:], dtype='float32')
        embeddings_dictionary[word] = vector_dimensions
    glove_file.close()

    embedding_matrix = np.zeros((vocab_size, 300))
    for word, index in vocab.items():
        embedding_vector = embeddings_dictionary.get(word)
        if embedding_vector is not None:
            embedding_matrix[index] = embedding_vector
    
    return embedding_matrix

# %%
def model_1():
    
    data = data_feature()
    embedding_matrix = embedding_glove()
    X = data[0]
    Y = data[1]
        
    #train et test data
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    
    model = Sequential()
    model.add(Embedding(vocab_size, 300, weights = [embedding_matrix], input_length= X_train.shape[1]))
    model.add(LSTM(32))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))
    
    
    # compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # summarize the model
    print(model.summary())    
    #plot the model
    #plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
    
    history = model.fit(X_train, y_train, epochs = 30, validation_split = 0.1, batch_size = 64)
    
    plt.clf()
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, 'g', label='Training loss')
    plt.plot(epochs, val_loss, 'y', label='Test loss')
    plt.title('Training and test loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    plt.clf()
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    plt.plot(epochs, acc, 'g', label='Training acc')
    plt.plot(epochs, val_acc, 'y', label='Test acc')
    plt.title('Training and test accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    
    p_train = model.predict(X_train)
    p_test = model.predict(X_test)
    
    p_train[p_train>0.5]=1 
    p_train[p_train<=0.5]=0 
    
    p_test[p_test>0.5]=1 
    p_test[p_test<=0.5]=0 
    
    
    # Accuracy
    train_acc = accuracy_score(y_train, p_train)
    test_acc = accuracy_score(y_test, p_test)
    
    # Confusion matrix
    train_cmat = confusion_matrix(y_train, p_train)
    test_cmat = confusion_matrix(y_test, p_test)
    
    # Perf
    print("Confusion train\n", train_cmat)
    print("Confusion test\n", test_cmat)
    print("Acc train\n", train_acc)
    print("Acc test\n", test_acc)

# %%
model_1()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 360, 300)          1048200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                42624
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,090,857
# Trainable params: 1,090,857
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 57 samples, validate on 7 samples
# Epoch 1/30
# 57/57 [==============================] - 1s 13ms/step - loss: 0.7041 - accuracy: 0.5439 - val_loss: 0.6742 - val_accuracy: 0.5714
# Epoch 2/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6928 - accuracy: 0.5965 - val_loss: 0.6746 - val_accuracy: 0.5714
# Epoch 3/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6889 - accuracy: 0.5614 - val_loss: 0.6755 - val_accuracy: 0.5714
# Epoch 4/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6779 - accuracy: 0.6491 - val_loss: 0.6764 - val_accuracy: 0.5714
# Epoch 5/30
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6663 - accuracy: 0.6491 - val_loss: 0.6774 - val_accuracy: 0.5714
# Epoch 6/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6596 - accuracy: 0.6842 - val_loss: 0.6784 - val_accuracy: 0.5714
# Epoch 7/30
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6492 - accuracy: 0.7018 - val_loss: 0.6796 - val_accuracy: 0.5714
# Epoch 8/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6441 - accuracy: 0.7193 - val_loss: 0.6810 - val_accuracy: 0.5714
# Epoch 9/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6332 - accuracy: 0.7018 - val_loss: 0.6824 - val_accuracy: 0.5714
# Epoch 10/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6268 - accuracy: 0.7018 - val_loss: 0.6838 - val_accuracy: 0.5714
# Epoch 11/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.6181 - accuracy: 0.7193 - val_loss: 0.6852 - val_accuracy: 0.5714
# Epoch 12/30
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6025 - accuracy: 0.7193 - val_loss: 0.6870 - val_accuracy: 0.5714
# Epoch 13/30
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6002 - accuracy: 0.7193 - val_loss: 0.6892 - val_accuracy: 0.5714
# Epoch 14/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5835 - accuracy: 0.7193 - val_loss: 0.6914 - val_accuracy: 0.5714
# Epoch 15/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5732 - accuracy: 0.7368 - val_loss: 0.6937 - val_accuracy: 0.5714
# Epoch 16/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5677 - accuracy: 0.7193 - val_loss: 0.6959 - val_accuracy: 0.5714
# Epoch 17/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5635 - accuracy: 0.7544 - val_loss: 0.6974 - val_accuracy: 0.5714
# Epoch 18/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5419 - accuracy: 0.7368 - val_loss: 0.6987 - val_accuracy: 0.4286
# Epoch 19/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5288 - accuracy: 0.7544 - val_loss: 0.6995 - val_accuracy: 0.5714
# Epoch 20/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.5233 - accuracy: 0.7719 - val_loss: 0.7000 - val_accuracy: 0.5714
# Epoch 21/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4934 - accuracy: 0.7719 - val_loss: 0.7011 - val_accuracy: 0.5714
# Epoch 22/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4713 - accuracy: 0.8070 - val_loss: 0.7032 - val_accuracy: 0.5714
# Epoch 23/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4582 - accuracy: 0.8421 - val_loss: 0.7048 - val_accuracy: 0.5714
# Epoch 24/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4235 - accuracy: 0.8596 - val_loss: 0.7053 - val_accuracy: 0.5714
# Epoch 25/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.4129 - accuracy: 0.8772 - val_loss: 0.7045 - val_accuracy: 0.5714
# Epoch 26/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3913 - accuracy: 0.8947 - val_loss: 0.7054 - val_accuracy: 0.5714
# Epoch 27/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3676 - accuracy: 0.8947 - val_loss: 0.7070 - val_accuracy: 0.7143
# Epoch 28/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3682 - accuracy: 0.9298 - val_loss: 0.7006 - val_accuracy: 0.5714
# Epoch 29/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3267 - accuracy: 0.9123 - val_loss: 0.6967 - val_accuracy: 0.5714
# Epoch 30/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3142 - accuracy: 0.9123 - val_loss: 0.6857 - val_accuracy: 0.5714
# Confusion train
#  [[24  5]
#  [ 3 32]]
# Confusion test
#  [[ 4  1]
#  [13 10]]
# Acc train
#  0.875
# Acc test
#  0.5

# %%
def model_lstm():
    
    data = data_feature()
    embedding_matrix = embedding_glove()
    X = data[0]
    Y = data[1]
        

    #train et test data
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    
    
    input_shape = Input(shape=(X_train.shape[1], ))
    embedding_layer = Embedding(vocab_size, 300, weights = [embedding_matrix])(input_shape)
    conv = Convolution1D(nb_filter=32, filter_length=3, border_mode='same', activation='relu')(embedding_layer)
    pool = MaxPooling1D(pool_length=2)(conv)
    LSTM_Layer = LSTM(128, dropout_W=0.2, dropout_U=0.2)(pool)
    dense_layer = Dense(64)(LSTM_Layer)
    Drop_2 = Dropout(0.25)(dense_layer)
    dense = Dense(1, activation = 'sigmoid')(Drop_2)
    model = Model(inputs = input_shape, outputs = dense)
    
    
    # compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # summarize the model
    print(model.summary())    
    #plot the model
    #plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
    
    history = model.fit(X_train, y_train, epochs = 30, validation_split = 0.1, batch_size = 64)
    
    plt.clf()
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, 'g', label='Training loss')
    plt.plot(epochs, val_loss, 'y', label='Test loss')
    plt.title('Training and test loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    plt.clf()
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    plt.plot(epochs, acc, 'g', label='Training acc')
    plt.plot(epochs, val_acc, 'y', label='Test acc')
    plt.title('Training and test accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    
    ### La prédiction de notre modèle
    p_train = model.predict(X_train)
    p_test = model.predict(X_test)
    
    p_train[p_train>0.5]=1 
    p_train[p_train<=0.5]=0 
    
    p_test[p_test>0.5]=1 
    p_test[p_test<=0.5]=0 
    
    
    # Accuracy
    train_acc = accuracy_score(y_train, p_train)
    test_acc = accuracy_score(y_test, p_test)
    
    # Confusion matrix
    train_cmat = confusion_matrix(y_train, p_train)
    test_cmat = confusion_matrix(y_test, p_test)
    
    # Perf
    print("Confusion train\n", train_cmat)
    print("Confusion test\n", test_cmat)
    print("Acc train\n", train_acc)
    print("Acc test\n", test_acc)

# %%
model_lstm()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 360)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 360, 300)          1048200
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 360, 32)           28832
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 180, 32)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               82432
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 1,167,785
# Trainable params: 1,167,785
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 57 samples, validate on 7 samples
# Epoch 1/30
# 57/57 [==============================] - 1s 15ms/step - loss: 0.6976 - accuracy: 0.4912 - val_loss: 0.6806 - val_accuracy: 0.5714
# Epoch 2/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6704 - accuracy: 0.7368 - val_loss: 0.6832 - val_accuracy: 0.5714
# Epoch 3/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.6140 - val_loss: 0.6881 - val_accuracy: 0.5714
# Epoch 4/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6696 - accuracy: 0.6491 - val_loss: 0.6877 - val_accuracy: 0.5714
# Epoch 5/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6599 - accuracy: 0.7193 - val_loss: 0.6823 - val_accuracy: 0.5714
# Epoch 6/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6285 - accuracy: 0.7544 - val_loss: 0.6767 - val_accuracy: 0.5714
# Epoch 7/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6297 - accuracy: 0.7018 - val_loss: 0.6661 - val_accuracy: 0.5714
# Epoch 8/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5855 - accuracy: 0.7544 - val_loss: 0.6602 - val_accuracy: 0.5714
# Epoch 9/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.6029 - accuracy: 0.7368 - val_loss: 0.6554 - val_accuracy: 0.5714
# Epoch 10/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5464 - accuracy: 0.7719 - val_loss: 0.6534 - val_accuracy: 0.5714
# Epoch 11/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.5252 - accuracy: 0.7719 - val_loss: 0.6517 - val_accuracy: 0.5714
# Epoch 12/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4668 - accuracy: 0.8070 - val_loss: 0.6334 - val_accuracy: 0.5714
# Epoch 13/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4855 - accuracy: 0.8070 - val_loss: 0.6350 - val_accuracy: 0.5714
# Epoch 14/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.4352 - accuracy: 0.8421 - val_loss: 0.6255 - val_accuracy: 0.5714
# Epoch 15/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3826 - accuracy: 0.8246 - val_loss: 0.6261 - val_accuracy: 0.5714
# Epoch 16/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.3497 - accuracy: 0.8772 - val_loss: 0.6542 - val_accuracy: 0.7143
# Epoch 17/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.3258 - accuracy: 0.8947 - val_loss: 0.6744 - val_accuracy: 0.7143
# Epoch 18/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.2820 - accuracy: 0.8947 - val_loss: 0.6556 - val_accuracy: 0.7143
# Epoch 19/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2660 - accuracy: 0.9123 - val_loss: 0.6228 - val_accuracy: 0.7143
# Epoch 20/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2401 - accuracy: 0.8947 - val_loss: 0.6176 - val_accuracy: 0.5714
# Epoch 21/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.2425 - accuracy: 0.9123 - val_loss: 0.6147 - val_accuracy: 0.5714
# Epoch 22/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.1712 - accuracy: 0.9298 - val_loss: 0.6397 - val_accuracy: 0.7143
# Epoch 23/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.1473 - accuracy: 0.9298 - val_loss: 0.7615 - val_accuracy: 0.7143
# Epoch 24/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.1196 - accuracy: 0.9298 - val_loss: 0.9071 - val_accuracy: 0.7143
# Epoch 25/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9298 - val_loss: 0.7554 - val_accuracy: 0.7143
# Epoch 26/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0698 - accuracy: 0.9825 - val_loss: 0.6813 - val_accuracy: 0.7143
# Epoch 27/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9474 - val_loss: 0.9855 - val_accuracy: 0.5714
# Epoch 28/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 1.2133 - val_accuracy: 0.5714
# Epoch 29/30
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0931 - accuracy: 0.9825 - val_loss: 1.2635 - val_accuracy: 0.5714
# Epoch 30/30
# 57/57 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9649 - val_loss: 0.9060 - val_accuracy: 0.8571
# Confusion train
#  [[28  1]
#  [ 1 34]]
# Confusion test
#  [[ 5  0]
#  [15  8]]
# Acc train
#  0.96875
# Acc test
#  0.4642857142857143
